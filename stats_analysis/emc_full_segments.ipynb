# %% [markdown]
# # EMC Feature Distribution Analysis (Full Segments)
#
# This notebook analyzes the distributions of EMC features extracted over the full segments, using the same approach as the 10s epochs analysis. It loads feature files, computes statistical tests, and visualizes the distributions for healthy and epileptic classes.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import pickle as pkl
from scipy.stats import mannwhitneyu
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler 
plt.style.use('ggplot')
import itertools as it

# extend the print line width
np.set_printoptions(linewidth=200)
pd.options.display.max_columns = None
pd.options.display.max_rows = None

#suppress runtimewarnings
import warnings 
warnings.filterwarnings("ignore", category=RuntimeWarning)

# EMC feature path and description
feature_path = '/space/gzanardini/emc_whole/split/'
feature_list = [file for file in os.listdir(feature_path) if file.endswith('.npy')]
description = pd.read_csv(os.path.join(feature_path, 'description.csv'))
labels = description['epilepsy'].values

# Mann-Whitney U test function
def mann_whitney_u_test(x, y):
    stat, p = mannwhitneyu(x, y, alternative='two-sided')
    return p

def handle_complex_numbers(features):
    if isinstance(features, pd.DataFrame):
        for column in features.columns:
            if np.iscomplexobj(features[column]):
                features[column] = features[column].apply(np.abs)
            features[column].replace([np.inf, -np.inf], np.nan, inplace=True)
    elif isinstance(features, np.ndarray):
        if np.iscomplexobj(features):
            features = np.abs(features)
        features[~np.isfinite(features)] = np.nan
    return features

# Sort the feature list
feature_list.sort()

feature_names = ['cc', 'cwt', 'dwt', 'gcc', 'gplv', 'plv', 'mst', 'sst', 'spectral', 'utm']
combiners=['mean', 'median', 'std', 'skew','kurt']
montages = ['CAR', 'BipolarDB','Cz','Laplacian']
segment_lengths=[1,2,5,10, 20, 60]

feature_dict = {}
for feature in feature_names:
    feature_dict[feature] = [f for f in feature_list if f.startswith(feature)]

# %%
lowest_pval_df = pd.DataFrame(columns=["Montage", "SegLength", 'Combiner', 'Feature Index', "LowestPValue"], index=feature_names)

significant_features_df = pd.DataFrame(columns=["FeatureName", "Montage", "SegLength", "Combiner", "FeaturesIndexs", "PValues" ])
# Create a DataFrame to store the lowest p-values and corresponding parameters for each feature

for feature in feature_names:
    lowest_pval_df.loc[feature, :] = [None, None, None, None, np.inf]
 
    for idx, (montage, segment_length, combiner) in enumerate(it.product(montages, segment_lengths, combiners)):
        print(feature, idx, montage, segment_length, combiner)
        feature_file = f"{feature}_{montage}_{segment_length}s_{combiner}.npy"
        features = np.load(os.path.join(feature_path, feature_file), allow_pickle=True)
        features = handle_complex_numbers(features)

        ps=np.array([mann_whitney_u_test(features[labels==0][:, i], features[labels==1][:, i]) for i in range(features.shape[1])])
        #apply bonferroni correction
        ps = ps * features.shape[1]
        ps = np.clip(ps, 0, 1)     
        lowest_indices = np.where(ps < 0.05)[0]
        lowest_indices_sorted = lowest_indices[np.argsort(ps[lowest_indices])]
        lowest_10 = lowest_indices_sorted[:10]
 
        significant = pd.DataFrame({
            "FeatureName": feature,
            "Montage": montage,
            "SegLength": segment_length,
            "Combiner": combiner,
            "FeaturesIndexs": lowest_indices_sorted.tolist(),
            "PValues": ps[lowest_indices_sorted].tolist()
        })

        significant_features_df = pd.concat([significant_features_df, significant], ignore_index=True)

        # Update the lowest p-value DataFrame
        if len(lowest_indices) > 0 and min(ps[lowest_indices]) < lowest_pval_df.loc[feature, 'LowestPValue']:
            lowest_pval_df.loc[feature, 'Montage'] = montage
            lowest_pval_df.loc[feature, 'SegLength'] = segment_length
            lowest_pval_df.loc[feature, 'Combiner'] = combiner
            lowest_pval_df.loc[feature, 'Feature Index'] = lowest_indices_sorted[0]
            lowest_pval_df.loc[feature, 'LowestPValue'] = ps[lowest_indices_sorted[0]]
# Out:
# cc 0 CAR 1 mean
# cc 1 CAR 1 median
# cc 2 CAR 1 std
# cc 3 CAR 1 skew
# cc 4 CAR 1 kurt
# cc 5 CAR 2 mean
# cc 6 CAR 2 median
# cc 7 CAR 2 std
# cc 8 CAR 2 skew
# cc 9 CAR 2 kurt
# cc 10 CAR 5 mean
# cc 11 CAR 5 median
# cc 12 CAR 5 std
# cc 13 CAR 5 skew
# cc 14 CAR 5 kurt
# cc 15 CAR 10 mean
# cc 16 CAR 10 median
# cc 17 CAR 10 std
# cc 18 CAR 10 skew
# cc 19 CAR 10 kurt
# cc 20 CAR 20 mean
# cc 21 CAR 20 median
# cc 22 CAR 20 std
# cc 23 CAR 20 skew
# cc 24 CAR 20 kurt
# cc 25 CAR 60 mean
# cc 26 CAR 60 median
# cc 27 CAR 60 std
# cc 28 CAR 60 skew
# cc 29 CAR 60 kurt
# cc 30 BipolarDB 1 mean
# cc 31 BipolarDB 1 median
# cc 32 BipolarDB 1 std
# cc 33 BipolarDB 1 skew
# cc 34 BipolarDB 1 kurt
# cc 35 BipolarDB 2 mean
# cc 36 BipolarDB 2 median
# cc 37 BipolarDB 2 std
# cc 38 BipolarDB 2 skew
# cc 39 BipolarDB 2 kurt
# cc 40 BipolarDB 5 mean
# cc 41 BipolarDB 5 median
# cc 42 BipolarDB 5 std
# cc 43 BipolarDB 5 skew
# cc 44 BipolarDB 5 kurt
# cc 45 BipolarDB 10 mean
# cc 46 BipolarDB 10 median
# cc 47 BipolarDB 10 std
# cc 48 BipolarDB 10 skew
# cc 49 BipolarDB 10 kurt
# cc 50 BipolarDB 20 mean
# cc 51 BipolarDB 20 median
# cc 52 BipolarDB 20 std
# cc 53 BipolarDB 20 skew
# cc 54 BipolarDB 20 kurt
# cc 55 BipolarDB 60 mean
# cc 56 BipolarDB 60 median
# cc 57 BipolarDB 60 std
# cc 58 BipolarDB 60 skew
# cc 59 BipolarDB 60 kurt
# cc 60 Cz 1 mean
# cc 61 Cz 1 median
# cc 62 Cz 1 std
# cc 63 Cz 1 skew
# cc 64 Cz 1 kurt
# cc 65 Cz 2 mean
# cc 66 Cz 2 median
# cc 67 Cz 2 std
# cc 68 Cz 2 skew
# cc 69 Cz 2 kurt
# cc 70 Cz 5 mean
# cc 71 Cz 5 median
# cc 72 Cz 5 std
# cc 73 Cz 5 skew
# cc 74 Cz 5 kurt
# cc 75 Cz 10 mean
# cc 76 Cz 10 median
# cc 77 Cz 10 std
# cc 78 Cz 10 skew
# cc 79 Cz 10 kurt
# cc 80 Cz 20 mean
# cc 81 Cz 20 median
# cc 82 Cz 20 std
# cc 83 Cz 20 skew
# cc 84 Cz 20 kurt
# cc 85 Cz 60 mean
# cc 86 Cz 60 median
# cc 87 Cz 60 std
# cc 88 Cz 60 skew
# cc 89 Cz 60 kurt
# cc 90 Laplacian 1 mean
# cc 91 Laplacian 1 median
# cc 92 Laplacian 1 std
# cc 93 Laplacian 1 skew
# cc 94 Laplacian 1 kurt
# cc 95 Laplacian 2 mean
# cc 96 Laplacian 2 median
# cc 97 Laplacian 2 std
# cc 98 Laplacian 2 skew
# cc 99 Laplacian 2 kurt
# cc 100 Laplacian 5 mean
# cc 101 Laplacian 5 median
# cc 102 Laplacian 5 std
# cc 103 Laplacian 5 skew
# cc 104 Laplacian 5 kurt
# cc 105 Laplacian 10 mean
# cc 106 Laplacian 10 median
# cc 107 Laplacian 10 std
# cc 108 Laplacian 10 skew
# cc 109 Laplacian 10 kurt
# cc 110 Laplacian 20 mean
# cc 111 Laplacian 20 median
# cc 112 Laplacian 20 std
# cc 113 Laplacian 20 skew
# cc 114 Laplacian 20 kurt
# cc 115 Laplacian 60 mean
# cc 116 Laplacian 60 median
# cc 117 Laplacian 60 std
# cc 118 Laplacian 60 skew
# cc 119 Laplacian 60 kurt
# cwt 0 CAR 1 mean
# cwt 1 CAR 1 median
# cwt 2 CAR 1 std
# cwt 3 CAR 1 skew
# cwt 4 CAR 1 kurt
# cwt 5 CAR 2 mean
# cwt 6 CAR 2 median
# cwt 7 CAR 2 std
# cwt 8 CAR 2 skew
# cwt 9 CAR 2 kurt
# cwt 10 CAR 5 mean
# cwt 11 CAR 5 median
# cwt 12 CAR 5 std
# cwt 13 CAR 5 skew
# cwt 14 CAR 5 kurt
# cwt 15 CAR 10 mean
# cwt 16 CAR 10 median
# cwt 17 CAR 10 std
# cwt 18 CAR 10 skew
# cwt 19 CAR 10 kurt
# cwt 20 CAR 20 mean
# cwt 21 CAR 20 median
# cwt 22 CAR 20 std
# cwt 23 CAR 20 skew
# cwt 24 CAR 20 kurt
# cwt 25 CAR 60 mean
# cwt 26 CAR 60 median
# cwt 27 CAR 60 std
# cwt 28 CAR 60 skew
# cwt 29 CAR 60 kurt
# cwt 30 BipolarDB 1 mean
# cwt 31 BipolarDB 1 median
# cwt 32 BipolarDB 1 std
# cwt 33 BipolarDB 1 skew
# cwt 34 BipolarDB 1 kurt
# cwt 35 BipolarDB 2 mean
# cwt 36 BipolarDB 2 median
# cwt 37 BipolarDB 2 std
# cwt 38 BipolarDB 2 skew
# cwt 39 BipolarDB 2 kurt
# cwt 40 BipolarDB 5 mean
# cwt 41 BipolarDB 5 median
# cwt 42 BipolarDB 5 std
# cwt 43 BipolarDB 5 skew
# cwt 44 BipolarDB 5 kurt
# cwt 45 BipolarDB 10 mean
# cwt 46 BipolarDB 10 median
# cwt 47 BipolarDB 10 std
# cwt 48 BipolarDB 10 skew
# cwt 49 BipolarDB 10 kurt
# cwt 50 BipolarDB 20 mean
# cwt 51 BipolarDB 20 median
# cwt 52 BipolarDB 20 std
# cwt 53 BipolarDB 20 skew
# cwt 54 BipolarDB 20 kurt
# cwt 55 BipolarDB 60 mean
# cwt 56 BipolarDB 60 median
# cwt 57 BipolarDB 60 std
# cwt 58 BipolarDB 60 skew
# cwt 59 BipolarDB 60 kurt
# cwt 60 Cz 1 mean
# cwt 61 Cz 1 median
# cwt 62 Cz 1 std
# cwt 63 Cz 1 skew
# cwt 64 Cz 1 kurt
# cwt 65 Cz 2 mean
# cwt 66 Cz 2 median
# cwt 67 Cz 2 std
# cwt 68 Cz 2 skew
# cwt 69 Cz 2 kurt
# cwt 70 Cz 5 mean
# cwt 71 Cz 5 median
# cwt 72 Cz 5 std
# cwt 73 Cz 5 skew
# cwt 74 Cz 5 kurt
# cwt 75 Cz 10 mean
# cwt 76 Cz 10 median
# cwt 77 Cz 10 std
# cwt 78 Cz 10 skew
# cwt 79 Cz 10 kurt
# cwt 80 Cz 20 mean
# cwt 81 Cz 20 median
# cwt 82 Cz 20 std
# cwt 83 Cz 20 skew
# cwt 84 Cz 20 kurt
# cwt 85 Cz 60 mean
# cwt 86 Cz 60 median
# cwt 87 Cz 60 std
# cwt 88 Cz 60 skew
# cwt 89 Cz 60 kurt
# cwt 90 Laplacian 1 mean
# cwt 91 Laplacian 1 median
# cwt 92 Laplacian 1 std
# cwt 93 Laplacian 1 skew
# cwt 94 Laplacian 1 kurt
# cwt 95 Laplacian 2 mean
# cwt 96 Laplacian 2 median
# cwt 97 Laplacian 2 std
# cwt 98 Laplacian 2 skew
# cwt 99 Laplacian 2 kurt
# cwt 100 Laplacian 5 mean
# cwt 101 Laplacian 5 median
# cwt 102 Laplacian 5 std
# cwt 103 Laplacian 5 skew
# cwt 104 Laplacian 5 kurt
# cwt 105 Laplacian 10 mean
# cwt 106 Laplacian 10 median
# cwt 107 Laplacian 10 std
# cwt 108 Laplacian 10 skew
# cwt 109 Laplacian 10 kurt
# cwt 110 Laplacian 20 mean
# cwt 111 Laplacian 20 median
# cwt 112 Laplacian 20 std
# cwt 113 Laplacian 20 skew
# cwt 114 Laplacian 20 kurt
# cwt 115 Laplacian 60 mean
# cwt 116 Laplacian 60 median
# cwt 117 Laplacian 60 std
# cwt 118 Laplacian 60 skew
# cwt 119 Laplacian 60 kurt
# dwt 0 CAR 1 mean
# dwt 1 CAR 1 median
# dwt 2 CAR 1 std
# dwt 3 CAR 1 skew
# dwt 4 CAR 1 kurt
# dwt 5 CAR 2 mean
# dwt 6 CAR 2 median
# dwt 7 CAR 2 std
# dwt 8 CAR 2 skew
# dwt 9 CAR 2 kurt
# dwt 10 CAR 5 mean
# dwt 11 CAR 5 median
# dwt 12 CAR 5 std
# dwt 13 CAR 5 skew
# dwt 14 CAR 5 kurt
# dwt 15 CAR 10 mean
# dwt 16 CAR 10 median
# dwt 17 CAR 10 std
# dwt 18 CAR 10 skew
# dwt 19 CAR 10 kurt
# dwt 20 CAR 20 mean
# dwt 21 CAR 20 median
# dwt 22 CAR 20 std
# dwt 23 CAR 20 skew
# dwt 24 CAR 20 kurt
# dwt 25 CAR 60 mean
# dwt 26 CAR 60 median
# dwt 27 CAR 60 std
# dwt 28 CAR 60 skew
# dwt 29 CAR 60 kurt
# dwt 30 BipolarDB 1 mean
# dwt 31 BipolarDB 1 median
# dwt 32 BipolarDB 1 std
# dwt 33 BipolarDB 1 skew
# dwt 34 BipolarDB 1 kurt
# dwt 35 BipolarDB 2 mean
# dwt 36 BipolarDB 2 median
# dwt 37 BipolarDB 2 std
# dwt 38 BipolarDB 2 skew
# dwt 39 BipolarDB 2 kurt
# dwt 40 BipolarDB 5 mean
# dwt 41 BipolarDB 5 median
# dwt 42 BipolarDB 5 std
# dwt 43 BipolarDB 5 skew
# dwt 44 BipolarDB 5 kurt
# dwt 45 BipolarDB 10 mean
# dwt 46 BipolarDB 10 median
# dwt 47 BipolarDB 10 std
# dwt 48 BipolarDB 10 skew
# dwt 49 BipolarDB 10 kurt
# dwt 50 BipolarDB 20 mean
# dwt 51 BipolarDB 20 median
# dwt 52 BipolarDB 20 std
# dwt 53 BipolarDB 20 skew
# dwt 54 BipolarDB 20 kurt
# dwt 55 BipolarDB 60 mean
# dwt 56 BipolarDB 60 median
# dwt 57 BipolarDB 60 std
# dwt 58 BipolarDB 60 skew
# dwt 59 BipolarDB 60 kurt
# dwt 60 Cz 1 mean
# dwt 61 Cz 1 median
# dwt 62 Cz 1 std
# dwt 63 Cz 1 skew
# dwt 64 Cz 1 kurt
# dwt 65 Cz 2 mean
# dwt 66 Cz 2 median
# dwt 67 Cz 2 std
# dwt 68 Cz 2 skew
# dwt 69 Cz 2 kurt
# dwt 70 Cz 5 mean
# dwt 71 Cz 5 median
# dwt 72 Cz 5 std
# dwt 73 Cz 5 skew
# dwt 74 Cz 5 kurt
# dwt 75 Cz 10 mean
# dwt 76 Cz 10 median
# dwt 77 Cz 10 std
# dwt 78 Cz 10 skew
# dwt 79 Cz 10 kurt
# dwt 80 Cz 20 mean
# dwt 81 Cz 20 median
# dwt 82 Cz 20 std
# dwt 83 Cz 20 skew
# dwt 84 Cz 20 kurt
# dwt 85 Cz 60 mean
# dwt 86 Cz 60 median
# dwt 87 Cz 60 std
# dwt 88 Cz 60 skew
# dwt 89 Cz 60 kurt
# dwt 90 Laplacian 1 mean
# dwt 91 Laplacian 1 median
# dwt 92 Laplacian 1 std
# dwt 93 Laplacian 1 skew
# dwt 94 Laplacian 1 kurt
# dwt 95 Laplacian 2 mean
# dwt 96 Laplacian 2 median
# dwt 97 Laplacian 2 std
# dwt 98 Laplacian 2 skew
# dwt 99 Laplacian 2 kurt
# dwt 100 Laplacian 5 mean
# dwt 101 Laplacian 5 median
# dwt 102 Laplacian 5 std
# dwt 103 Laplacian 5 skew
# dwt 104 Laplacian 5 kurt
# dwt 105 Laplacian 10 mean
# dwt 106 Laplacian 10 median
# dwt 107 Laplacian 10 std
# dwt 108 Laplacian 10 skew
# dwt 109 Laplacian 10 kurt
# dwt 110 Laplacian 20 mean
# dwt 111 Laplacian 20 median
# dwt 112 Laplacian 20 std
# dwt 113 Laplacian 20 skew
# dwt 114 Laplacian 20 kurt
# dwt 115 Laplacian 60 mean
# dwt 116 Laplacian 60 median
# dwt 117 Laplacian 60 std
# dwt 118 Laplacian 60 skew
# dwt 119 Laplacian 60 kurt
# gcc 0 CAR 1 mean
# gcc 1 CAR 1 median
# gcc 2 CAR 1 std
# gcc 3 CAR 1 skew
# gcc 4 CAR 1 kurt
# gcc 5 CAR 2 mean
# gcc 6 CAR 2 median
# gcc 7 CAR 2 std
# gcc 8 CAR 2 skew
# gcc 9 CAR 2 kurt
# gcc 10 CAR 5 mean
# gcc 11 CAR 5 median
# gcc 12 CAR 5 std
# gcc 13 CAR 5 skew
# gcc 14 CAR 5 kurt
# gcc 15 CAR 10 mean
# gcc 16 CAR 10 median
# gcc 17 CAR 10 std
# gcc 18 CAR 10 skew
# gcc 19 CAR 10 kurt
# gcc 20 CAR 20 mean
# gcc 21 CAR 20 median
# gcc 22 CAR 20 std
# gcc 23 CAR 20 skew
# gcc 24 CAR 20 kurt
# gcc 25 CAR 60 mean
# gcc 26 CAR 60 median
# gcc 27 CAR 60 std
# gcc 28 CAR 60 skew
# gcc 29 CAR 60 kurt
# gcc 30 BipolarDB 1 mean
# gcc 31 BipolarDB 1 median
# gcc 32 BipolarDB 1 std
# gcc 33 BipolarDB 1 skew
# gcc 34 BipolarDB 1 kurt
# gcc 35 BipolarDB 2 mean
# gcc 36 BipolarDB 2 median
# gcc 37 BipolarDB 2 std
# gcc 38 BipolarDB 2 skew
# gcc 39 BipolarDB 2 kurt
# gcc 40 BipolarDB 5 mean
# gcc 41 BipolarDB 5 median
# gcc 42 BipolarDB 5 std
# gcc 43 BipolarDB 5 skew
# gcc 44 BipolarDB 5 kurt
# gcc 45 BipolarDB 10 mean
# gcc 46 BipolarDB 10 median
# gcc 47 BipolarDB 10 std
# gcc 48 BipolarDB 10 skew
# gcc 49 BipolarDB 10 kurt
# gcc 50 BipolarDB 20 mean
# gcc 51 BipolarDB 20 median
# gcc 52 BipolarDB 20 std
# gcc 53 BipolarDB 20 skew
# gcc 54 BipolarDB 20 kurt
# gcc 55 BipolarDB 60 mean
# gcc 56 BipolarDB 60 median
# gcc 57 BipolarDB 60 std
# gcc 58 BipolarDB 60 skew
# gcc 59 BipolarDB 60 kurt
# gcc 60 Cz 1 mean
# gcc 61 Cz 1 median
# gcc 62 Cz 1 std
# gcc 63 Cz 1 skew
# gcc 64 Cz 1 kurt
# gcc 65 Cz 2 mean
# gcc 66 Cz 2 median
# gcc 67 Cz 2 std
# gcc 68 Cz 2 skew
# gcc 69 Cz 2 kurt
# gcc 70 Cz 5 mean
# gcc 71 Cz 5 median
# gcc 72 Cz 5 std
# gcc 73 Cz 5 skew
# gcc 74 Cz 5 kurt
# gcc 75 Cz 10 mean
# gcc 76 Cz 10 median
# gcc 77 Cz 10 std
# gcc 78 Cz 10 skew
# gcc 79 Cz 10 kurt
# gcc 80 Cz 20 mean
# gcc 81 Cz 20 median
# gcc 82 Cz 20 std
# gcc 83 Cz 20 skew
# gcc 84 Cz 20 kurt
# gcc 85 Cz 60 mean
# gcc 86 Cz 60 median
# gcc 87 Cz 60 std
# gcc 88 Cz 60 skew
# gcc 89 Cz 60 kurt
# gcc 90 Laplacian 1 mean
# gcc 91 Laplacian 1 median
# gcc 92 Laplacian 1 std
# gcc 93 Laplacian 1 skew
# gcc 94 Laplacian 1 kurt
# gcc 95 Laplacian 2 mean
# gcc 96 Laplacian 2 median
# gcc 97 Laplacian 2 std
# gcc 98 Laplacian 2 skew
# gcc 99 Laplacian 2 kurt
# gcc 100 Laplacian 5 mean
# gcc 101 Laplacian 5 median
# gcc 102 Laplacian 5 std
# gcc 103 Laplacian 5 skew
# gcc 104 Laplacian 5 kurt
# gcc 105 Laplacian 10 mean
# gcc 106 Laplacian 10 median
# gcc 107 Laplacian 10 std
# gcc 108 Laplacian 10 skew
# gcc 109 Laplacian 10 kurt
# gcc 110 Laplacian 20 mean
# gcc 111 Laplacian 20 median
# gcc 112 Laplacian 20 std
# gcc 113 Laplacian 20 skew
# gcc 114 Laplacian 20 kurt
# gcc 115 Laplacian 60 mean
# gcc 116 Laplacian 60 median
# gcc 117 Laplacian 60 std
# gcc 118 Laplacian 60 skew
# gcc 119 Laplacian 60 kurt
# gplv 0 CAR 1 mean
# gplv 1 CAR 1 median
# gplv 2 CAR 1 std
# gplv 3 CAR 1 skew
# gplv 4 CAR 1 kurt
# gplv 5 CAR 2 mean
# gplv 6 CAR 2 median
# gplv 7 CAR 2 std
# gplv 8 CAR 2 skew
# gplv 9 CAR 2 kurt
# gplv 10 CAR 5 mean
# gplv 11 CAR 5 median
# gplv 12 CAR 5 std
# gplv 13 CAR 5 skew
# gplv 14 CAR 5 kurt
# gplv 15 CAR 10 mean
# gplv 16 CAR 10 median
# gplv 17 CAR 10 std
# gplv 18 CAR 10 skew
# gplv 19 CAR 10 kurt
# gplv 20 CAR 20 mean
# gplv 21 CAR 20 median
# gplv 22 CAR 20 std
# gplv 23 CAR 20 skew
# gplv 24 CAR 20 kurt
# gplv 25 CAR 60 mean
# gplv 26 CAR 60 median
# gplv 27 CAR 60 std
# gplv 28 CAR 60 skew
# gplv 29 CAR 60 kurt
# gplv 30 BipolarDB 1 mean
# gplv 31 BipolarDB 1 median
# gplv 32 BipolarDB 1 std
# gplv 33 BipolarDB 1 skew
# gplv 34 BipolarDB 1 kurt
# gplv 35 BipolarDB 2 mean
# gplv 36 BipolarDB 2 median
# gplv 37 BipolarDB 2 std
# gplv 38 BipolarDB 2 skew
# gplv 39 BipolarDB 2 kurt
# gplv 40 BipolarDB 5 mean
# gplv 41 BipolarDB 5 median
# gplv 42 BipolarDB 5 std
# gplv 43 BipolarDB 5 skew
# gplv 44 BipolarDB 5 kurt
# gplv 45 BipolarDB 10 mean
# gplv 46 BipolarDB 10 median
# gplv 47 BipolarDB 10 std
# gplv 48 BipolarDB 10 skew
# gplv 49 BipolarDB 10 kurt
# gplv 50 BipolarDB 20 mean
# gplv 51 BipolarDB 20 median
# gplv 52 BipolarDB 20 std
# gplv 53 BipolarDB 20 skew
# gplv 54 BipolarDB 20 kurt
# gplv 55 BipolarDB 60 mean
# gplv 56 BipolarDB 60 median
# gplv 57 BipolarDB 60 std
# gplv 58 BipolarDB 60 skew
# gplv 59 BipolarDB 60 kurt
# gplv 60 Cz 1 mean
# gplv 61 Cz 1 median
# gplv 62 Cz 1 std
# gplv 63 Cz 1 skew
# gplv 64 Cz 1 kurt
# gplv 65 Cz 2 mean
# gplv 66 Cz 2 median
# gplv 67 Cz 2 std
# gplv 68 Cz 2 skew
# gplv 69 Cz 2 kurt
# gplv 70 Cz 5 mean
# gplv 71 Cz 5 median
# gplv 72 Cz 5 std
# gplv 73 Cz 5 skew
# gplv 74 Cz 5 kurt
# gplv 75 Cz 10 mean
# gplv 76 Cz 10 median
# gplv 77 Cz 10 std
# gplv 78 Cz 10 skew
# gplv 79 Cz 10 kurt
# gplv 80 Cz 20 mean
# gplv 81 Cz 20 median
# gplv 82 Cz 20 std
# gplv 83 Cz 20 skew
# gplv 84 Cz 20 kurt
# gplv 85 Cz 60 mean
# gplv 86 Cz 60 median
# gplv 87 Cz 60 std
# gplv 88 Cz 60 skew
# gplv 89 Cz 60 kurt
# gplv 90 Laplacian 1 mean
# gplv 91 Laplacian 1 median
# gplv 92 Laplacian 1 std
# gplv 93 Laplacian 1 skew
# gplv 94 Laplacian 1 kurt
# gplv 95 Laplacian 2 mean
# gplv 96 Laplacian 2 median
# gplv 97 Laplacian 2 std
# gplv 98 Laplacian 2 skew
# gplv 99 Laplacian 2 kurt
# gplv 100 Laplacian 5 mean
# gplv 101 Laplacian 5 median
# gplv 102 Laplacian 5 std
# gplv 103 Laplacian 5 skew
# gplv 104 Laplacian 5 kurt
# gplv 105 Laplacian 10 mean
# gplv 106 Laplacian 10 median
# gplv 107 Laplacian 10 std
# gplv 108 Laplacian 10 skew
# gplv 109 Laplacian 10 kurt
# gplv 110 Laplacian 20 mean
# gplv 111 Laplacian 20 median
# gplv 112 Laplacian 20 std
# gplv 113 Laplacian 20 skew
# gplv 114 Laplacian 20 kurt
# gplv 115 Laplacian 60 mean
# gplv 116 Laplacian 60 median
# gplv 117 Laplacian 60 std
# gplv 118 Laplacian 60 skew
# gplv 119 Laplacian 60 kurt
# plv 0 CAR 1 mean
# plv 1 CAR 1 median
# plv 2 CAR 1 std
# plv 3 CAR 1 skew
# plv 4 CAR 1 kurt
# plv 5 CAR 2 mean
# plv 6 CAR 2 median
# plv 7 CAR 2 std
# plv 8 CAR 2 skew
# plv 9 CAR 2 kurt
# plv 10 CAR 5 mean
# plv 11 CAR 5 median
# plv 12 CAR 5 std
# plv 13 CAR 5 skew
# plv 14 CAR 5 kurt
# plv 15 CAR 10 mean
# plv 16 CAR 10 median
# plv 17 CAR 10 std
# plv 18 CAR 10 skew
# plv 19 CAR 10 kurt
# plv 20 CAR 20 mean
# plv 21 CAR 20 median
# plv 22 CAR 20 std
# plv 23 CAR 20 skew
# plv 24 CAR 20 kurt
# plv 25 CAR 60 mean
# plv 26 CAR 60 median
# plv 27 CAR 60 std
# plv 28 CAR 60 skew
# plv 29 CAR 60 kurt
# plv 30 BipolarDB 1 mean
# plv 31 BipolarDB 1 median
# plv 32 BipolarDB 1 std
# plv 33 BipolarDB 1 skew
# plv 34 BipolarDB 1 kurt
# plv 35 BipolarDB 2 mean
# plv 36 BipolarDB 2 median
# plv 37 BipolarDB 2 std
# plv 38 BipolarDB 2 skew
# plv 39 BipolarDB 2 kurt
# plv 40 BipolarDB 5 mean
# plv 41 BipolarDB 5 median
# plv 42 BipolarDB 5 std
# plv 43 BipolarDB 5 skew
# plv 44 BipolarDB 5 kurt
# plv 45 BipolarDB 10 mean
# plv 46 BipolarDB 10 median
# plv 47 BipolarDB 10 std
# plv 48 BipolarDB 10 skew
# plv 49 BipolarDB 10 kurt
# plv 50 BipolarDB 20 mean
# plv 51 BipolarDB 20 median
# plv 52 BipolarDB 20 std
# plv 53 BipolarDB 20 skew
# plv 54 BipolarDB 20 kurt
# plv 55 BipolarDB 60 mean
# plv 56 BipolarDB 60 median
# plv 57 BipolarDB 60 std
# plv 58 BipolarDB 60 skew
# plv 59 BipolarDB 60 kurt
# plv 60 Cz 1 mean
# plv 61 Cz 1 median
# plv 62 Cz 1 std
# plv 63 Cz 1 skew
# plv 64 Cz 1 kurt
# plv 65 Cz 2 mean
# plv 66 Cz 2 median
# plv 67 Cz 2 std
# plv 68 Cz 2 skew
# plv 69 Cz 2 kurt
# plv 70 Cz 5 mean
# plv 71 Cz 5 median
# plv 72 Cz 5 std
# plv 73 Cz 5 skew
# plv 74 Cz 5 kurt
# plv 75 Cz 10 mean
# plv 76 Cz 10 median
# plv 77 Cz 10 std
# plv 78 Cz 10 skew
# plv 79 Cz 10 kurt
# plv 80 Cz 20 mean
# plv 81 Cz 20 median
# plv 82 Cz 20 std
# plv 83 Cz 20 skew
# plv 84 Cz 20 kurt
# plv 85 Cz 60 mean
# plv 86 Cz 60 median
# plv 87 Cz 60 std
# plv 88 Cz 60 skew
# plv 89 Cz 60 kurt
# plv 90 Laplacian 1 mean
# plv 91 Laplacian 1 median
# plv 92 Laplacian 1 std
# plv 93 Laplacian 1 skew
# plv 94 Laplacian 1 kurt
# plv 95 Laplacian 2 mean
# plv 96 Laplacian 2 median
# plv 97 Laplacian 2 std
# plv 98 Laplacian 2 skew
# plv 99 Laplacian 2 kurt
# plv 100 Laplacian 5 mean
# plv 101 Laplacian 5 median
# plv 102 Laplacian 5 std
# plv 103 Laplacian 5 skew
# plv 104 Laplacian 5 kurt
# plv 105 Laplacian 10 mean
# plv 106 Laplacian 10 median
# plv 107 Laplacian 10 std
# plv 108 Laplacian 10 skew
# plv 109 Laplacian 10 kurt
# plv 110 Laplacian 20 mean
# plv 111 Laplacian 20 median
# plv 112 Laplacian 20 std
# plv 113 Laplacian 20 skew
# plv 114 Laplacian 20 kurt
# plv 115 Laplacian 60 mean
# plv 116 Laplacian 60 median
# plv 117 Laplacian 60 std
# plv 118 Laplacian 60 skew
# plv 119 Laplacian 60 kurt
# mst 0 CAR 1 mean
# mst 1 CAR 1 median
# mst 2 CAR 1 std
# mst 3 CAR 1 skew
# mst 4 CAR 1 kurt
# mst 5 CAR 2 mean
# mst 6 CAR 2 median
# mst 7 CAR 2 std
# mst 8 CAR 2 skew
# mst 9 CAR 2 kurt
# mst 10 CAR 5 mean
# mst 11 CAR 5 median
# mst 12 CAR 5 std
# mst 13 CAR 5 skew
# mst 14 CAR 5 kurt
# mst 15 CAR 10 mean
# mst 16 CAR 10 median
# mst 17 CAR 10 std
# mst 18 CAR 10 skew
# mst 19 CAR 10 kurt
# mst 20 CAR 20 mean
# mst 21 CAR 20 median
# mst 22 CAR 20 std
# mst 23 CAR 20 skew
# mst 24 CAR 20 kurt
# mst 25 CAR 60 mean
# mst 26 CAR 60 median
# mst 27 CAR 60 std
# mst 28 CAR 60 skew
# mst 29 CAR 60 kurt
# mst 30 BipolarDB 1 mean
# mst 31 BipolarDB 1 median
# mst 32 BipolarDB 1 std
# mst 33 BipolarDB 1 skew
# mst 34 BipolarDB 1 kurt
# mst 35 BipolarDB 2 mean
# mst 36 BipolarDB 2 median
# mst 37 BipolarDB 2 std
# mst 38 BipolarDB 2 skew
# mst 39 BipolarDB 2 kurt
# mst 40 BipolarDB 5 mean
# mst 41 BipolarDB 5 median
# mst 42 BipolarDB 5 std
# mst 43 BipolarDB 5 skew
# mst 44 BipolarDB 5 kurt
# mst 45 BipolarDB 10 mean
# mst 46 BipolarDB 10 median
# mst 47 BipolarDB 10 std
# mst 48 BipolarDB 10 skew
# mst 49 BipolarDB 10 kurt
# mst 50 BipolarDB 20 mean
# mst 51 BipolarDB 20 median
# mst 52 BipolarDB 20 std
# mst 53 BipolarDB 20 skew
# mst 54 BipolarDB 20 kurt
# mst 55 BipolarDB 60 mean
# mst 56 BipolarDB 60 median
# mst 57 BipolarDB 60 std
# mst 58 BipolarDB 60 skew
# mst 59 BipolarDB 60 kurt
# mst 60 Cz 1 mean
# mst 61 Cz 1 median
# mst 62 Cz 1 std
# mst 63 Cz 1 skew
# mst 64 Cz 1 kurt
# mst 65 Cz 2 mean
# mst 66 Cz 2 median
# mst 67 Cz 2 std
# mst 68 Cz 2 skew
# mst 69 Cz 2 kurt
# mst 70 Cz 5 mean
# mst 71 Cz 5 median
# mst 72 Cz 5 std
# mst 73 Cz 5 skew
# mst 74 Cz 5 kurt
# mst 75 Cz 10 mean
# mst 76 Cz 10 median
# mst 77 Cz 10 std
# mst 78 Cz 10 skew
# mst 79 Cz 10 kurt
# mst 80 Cz 20 mean
# mst 81 Cz 20 median
# mst 82 Cz 20 std
# mst 83 Cz 20 skew
# mst 84 Cz 20 kurt
# mst 85 Cz 60 mean
# mst 86 Cz 60 median
# mst 87 Cz 60 std
# mst 88 Cz 60 skew
# mst 89 Cz 60 kurt
# mst 90 Laplacian 1 mean
# mst 91 Laplacian 1 median
# mst 92 Laplacian 1 std
# mst 93 Laplacian 1 skew
# mst 94 Laplacian 1 kurt
# mst 95 Laplacian 2 mean
# mst 96 Laplacian 2 median
# mst 97 Laplacian 2 std
# mst 98 Laplacian 2 skew
# mst 99 Laplacian 2 kurt
# mst 100 Laplacian 5 mean
# mst 101 Laplacian 5 median
# mst 102 Laplacian 5 std
# mst 103 Laplacian 5 skew
# mst 104 Laplacian 5 kurt
# mst 105 Laplacian 10 mean
# mst 106 Laplacian 10 median
# mst 107 Laplacian 10 std
# mst 108 Laplacian 10 skew
# mst 109 Laplacian 10 kurt
# mst 110 Laplacian 20 mean
# mst 111 Laplacian 20 median
# mst 112 Laplacian 20 std
# mst 113 Laplacian 20 skew
# mst 114 Laplacian 20 kurt
# mst 115 Laplacian 60 mean
# mst 116 Laplacian 60 median
# mst 117 Laplacian 60 std
# mst 118 Laplacian 60 skew
# mst 119 Laplacian 60 kurt
# sst 0 CAR 1 mean
# sst 1 CAR 1 median
# sst 2 CAR 1 std
# sst 3 CAR 1 skew
# sst 4 CAR 1 kurt
# sst 5 CAR 2 mean
# sst 6 CAR 2 median
# sst 7 CAR 2 std
# sst 8 CAR 2 skew
# sst 9 CAR 2 kurt
# sst 10 CAR 5 mean
# sst 11 CAR 5 median
# sst 12 CAR 5 std
# sst 13 CAR 5 skew
# sst 14 CAR 5 kurt
# sst 15 CAR 10 mean
# sst 16 CAR 10 median
# sst 17 CAR 10 std
# sst 18 CAR 10 skew
# sst 19 CAR 10 kurt
# sst 20 CAR 20 mean
# sst 21 CAR 20 median
# sst 22 CAR 20 std
# sst 23 CAR 20 skew
# sst 24 CAR 20 kurt
# sst 25 CAR 60 mean
# sst 26 CAR 60 median
# sst 27 CAR 60 std
# sst 28 CAR 60 skew
# sst 29 CAR 60 kurt
# sst 30 BipolarDB 1 mean
# sst 31 BipolarDB 1 median
# sst 32 BipolarDB 1 std
# sst 33 BipolarDB 1 skew
# sst 34 BipolarDB 1 kurt
# sst 35 BipolarDB 2 mean
# sst 36 BipolarDB 2 median
# sst 37 BipolarDB 2 std
# sst 38 BipolarDB 2 skew
# sst 39 BipolarDB 2 kurt
# sst 40 BipolarDB 5 mean
# sst 41 BipolarDB 5 median
# sst 42 BipolarDB 5 std
# sst 43 BipolarDB 5 skew
# sst 44 BipolarDB 5 kurt
# sst 45 BipolarDB 10 mean
# sst 46 BipolarDB 10 median
# sst 47 BipolarDB 10 std
# sst 48 BipolarDB 10 skew
# sst 49 BipolarDB 10 kurt
# sst 50 BipolarDB 20 mean
# sst 51 BipolarDB 20 median
# sst 52 BipolarDB 20 std
# sst 53 BipolarDB 20 skew
# sst 54 BipolarDB 20 kurt
# sst 55 BipolarDB 60 mean
# sst 56 BipolarDB 60 median
# sst 57 BipolarDB 60 std
# sst 58 BipolarDB 60 skew
# sst 59 BipolarDB 60 kurt
# sst 60 Cz 1 mean
# sst 61 Cz 1 median
# sst 62 Cz 1 std
# sst 63 Cz 1 skew
# sst 64 Cz 1 kurt
# sst 65 Cz 2 mean
# sst 66 Cz 2 median
# sst 67 Cz 2 std
# sst 68 Cz 2 skew
# sst 69 Cz 2 kurt
# sst 70 Cz 5 mean
# sst 71 Cz 5 median
# sst 72 Cz 5 std
# sst 73 Cz 5 skew
# sst 74 Cz 5 kurt
# sst 75 Cz 10 mean
# sst 76 Cz 10 median
# sst 77 Cz 10 std
# sst 78 Cz 10 skew
# sst 79 Cz 10 kurt
# sst 80 Cz 20 mean
# sst 81 Cz 20 median
# sst 82 Cz 20 std
# sst 83 Cz 20 skew
# sst 84 Cz 20 kurt
# sst 85 Cz 60 mean
# sst 86 Cz 60 median
# sst 87 Cz 60 std
# sst 88 Cz 60 skew
# sst 89 Cz 60 kurt
# sst 90 Laplacian 1 mean
# sst 91 Laplacian 1 median
# sst 92 Laplacian 1 std
# sst 93 Laplacian 1 skew
# sst 94 Laplacian 1 kurt
# sst 95 Laplacian 2 mean
# sst 96 Laplacian 2 median
# sst 97 Laplacian 2 std
# sst 98 Laplacian 2 skew
# sst 99 Laplacian 2 kurt
# sst 100 Laplacian 5 mean
# sst 101 Laplacian 5 median
# sst 102 Laplacian 5 std
# sst 103 Laplacian 5 skew
# sst 104 Laplacian 5 kurt
# sst 105 Laplacian 10 mean
# sst 106 Laplacian 10 median
# sst 107 Laplacian 10 std
# sst 108 Laplacian 10 skew
# sst 109 Laplacian 10 kurt
# sst 110 Laplacian 20 mean
# sst 111 Laplacian 20 median
# sst 112 Laplacian 20 std
# sst 113 Laplacian 20 skew
# sst 114 Laplacian 20 kurt
# sst 115 Laplacian 60 mean
# sst 116 Laplacian 60 median
# sst 117 Laplacian 60 std
# sst 118 Laplacian 60 skew
# sst 119 Laplacian 60 kurt
# spectral 0 CAR 1 mean
# spectral 1 CAR 1 median
# spectral 2 CAR 1 std
# spectral 3 CAR 1 skew
# spectral 4 CAR 1 kurt
# spectral 5 CAR 2 mean
# spectral 6 CAR 2 median
# spectral 7 CAR 2 std
# spectral 8 CAR 2 skew
# spectral 9 CAR 2 kurt
# spectral 10 CAR 5 mean
# spectral 11 CAR 5 median
# spectral 12 CAR 5 std
# spectral 13 CAR 5 skew
# spectral 14 CAR 5 kurt
# spectral 15 CAR 10 mean
# spectral 16 CAR 10 median
# spectral 17 CAR 10 std
# spectral 18 CAR 10 skew
# spectral 19 CAR 10 kurt
# spectral 20 CAR 20 mean
# spectral 21 CAR 20 median
# spectral 22 CAR 20 std
# spectral 23 CAR 20 skew
# spectral 24 CAR 20 kurt
# spectral 25 CAR 60 mean
# spectral 26 CAR 60 median
# spectral 27 CAR 60 std
# spectral 28 CAR 60 skew
# spectral 29 CAR 60 kurt
# spectral 30 BipolarDB 1 mean
# spectral 31 BipolarDB 1 median
# spectral 32 BipolarDB 1 std
# spectral 33 BipolarDB 1 skew
# spectral 34 BipolarDB 1 kurt
# spectral 35 BipolarDB 2 mean
# spectral 36 BipolarDB 2 median
# spectral 37 BipolarDB 2 std
# spectral 38 BipolarDB 2 skew
# spectral 39 BipolarDB 2 kurt
# spectral 40 BipolarDB 5 mean
# spectral 41 BipolarDB 5 median
# spectral 42 BipolarDB 5 std
# spectral 43 BipolarDB 5 skew
# spectral 44 BipolarDB 5 kurt
# spectral 45 BipolarDB 10 mean
# spectral 46 BipolarDB 10 median
# spectral 47 BipolarDB 10 std
# spectral 48 BipolarDB 10 skew
# spectral 49 BipolarDB 10 kurt
# spectral 50 BipolarDB 20 mean
# spectral 51 BipolarDB 20 median
# spectral 52 BipolarDB 20 std
# spectral 53 BipolarDB 20 skew
# spectral 54 BipolarDB 20 kurt
# spectral 55 BipolarDB 60 mean
# spectral 56 BipolarDB 60 median
# spectral 57 BipolarDB 60 std
# spectral 58 BipolarDB 60 skew
# spectral 59 BipolarDB 60 kurt
# spectral 60 Cz 1 mean
# spectral 61 Cz 1 median
# spectral 62 Cz 1 std
# spectral 63 Cz 1 skew
# spectral 64 Cz 1 kurt
# spectral 65 Cz 2 mean
# spectral 66 Cz 2 median
# spectral 67 Cz 2 std
# spectral 68 Cz 2 skew
# spectral 69 Cz 2 kurt
# spectral 70 Cz 5 mean
# spectral 71 Cz 5 median
# spectral 72 Cz 5 std
# spectral 73 Cz 5 skew
# spectral 74 Cz 5 kurt
# spectral 75 Cz 10 mean
# spectral 76 Cz 10 median
# spectral 77 Cz 10 std
# spectral 78 Cz 10 skew
# spectral 79 Cz 10 kurt
# spectral 80 Cz 20 mean
# spectral 81 Cz 20 median
# spectral 82 Cz 20 std
# spectral 83 Cz 20 skew
# spectral 84 Cz 20 kurt
# spectral 85 Cz 60 mean
# spectral 86 Cz 60 median
# spectral 87 Cz 60 std
# spectral 88 Cz 60 skew
# spectral 89 Cz 60 kurt
# spectral 90 Laplacian 1 mean
# spectral 91 Laplacian 1 median
# spectral 92 Laplacian 1 std
# spectral 93 Laplacian 1 skew
# spectral 94 Laplacian 1 kurt
# spectral 95 Laplacian 2 mean
# spectral 96 Laplacian 2 median
# spectral 97 Laplacian 2 std
# spectral 98 Laplacian 2 skew
# spectral 99 Laplacian 2 kurt
# spectral 100 Laplacian 5 mean
# spectral 101 Laplacian 5 median
# spectral 102 Laplacian 5 std
# spectral 103 Laplacian 5 skew
# spectral 104 Laplacian 5 kurt
# spectral 105 Laplacian 10 mean
# spectral 106 Laplacian 10 median
# spectral 107 Laplacian 10 std
# spectral 108 Laplacian 10 skew
# spectral 109 Laplacian 10 kurt
# spectral 110 Laplacian 20 mean
# spectral 111 Laplacian 20 median
# spectral 112 Laplacian 20 std
# spectral 113 Laplacian 20 skew
# spectral 114 Laplacian 20 kurt
# spectral 115 Laplacian 60 mean
# spectral 116 Laplacian 60 median
# spectral 117 Laplacian 60 std
# spectral 118 Laplacian 60 skew
# spectral 119 Laplacian 60 kurt
# utm 0 CAR 1 mean
# utm 1 CAR 1 median
# utm 2 CAR 1 std
# utm 3 CAR 1 skew
# utm 4 CAR 1 kurt
# utm 5 CAR 2 mean
# utm 6 CAR 2 median
# utm 7 CAR 2 std
# utm 8 CAR 2 skew
# utm 9 CAR 2 kurt
# utm 10 CAR 5 mean
# utm 11 CAR 5 median
# utm 12 CAR 5 std
# utm 13 CAR 5 skew
# utm 14 CAR 5 kurt
# utm 15 CAR 10 mean
# utm 16 CAR 10 median
# utm 17 CAR 10 std
# utm 18 CAR 10 skew
# utm 19 CAR 10 kurt
# utm 20 CAR 20 mean
# utm 21 CAR 20 median
# utm 22 CAR 20 std
# utm 23 CAR 20 skew
# utm 24 CAR 20 kurt
# utm 25 CAR 60 mean
# utm 26 CAR 60 median
# utm 27 CAR 60 std
# utm 28 CAR 60 skew
# utm 29 CAR 60 kurt
# utm 30 BipolarDB 1 mean
# utm 31 BipolarDB 1 median
# utm 32 BipolarDB 1 std
# utm 33 BipolarDB 1 skew
# utm 34 BipolarDB 1 kurt
# utm 35 BipolarDB 2 mean
# utm 36 BipolarDB 2 median
# utm 37 BipolarDB 2 std
# utm 38 BipolarDB 2 skew
# utm 39 BipolarDB 2 kurt
# utm 40 BipolarDB 5 mean
# utm 41 BipolarDB 5 median
# utm 42 BipolarDB 5 std
# utm 43 BipolarDB 5 skew
# utm 44 BipolarDB 5 kurt
# utm 45 BipolarDB 10 mean
# utm 46 BipolarDB 10 median
# utm 47 BipolarDB 10 std
# utm 48 BipolarDB 10 skew
# utm 49 BipolarDB 10 kurt
# utm 50 BipolarDB 20 mean
# utm 51 BipolarDB 20 median
# utm 52 BipolarDB 20 std
# utm 53 BipolarDB 20 skew
# utm 54 BipolarDB 20 kurt
# utm 55 BipolarDB 60 mean
# utm 56 BipolarDB 60 median
# utm 57 BipolarDB 60 std
# utm 58 BipolarDB 60 skew
# utm 59 BipolarDB 60 kurt
# utm 60 Cz 1 mean
# utm 61 Cz 1 median
# utm 62 Cz 1 std
# utm 63 Cz 1 skew
# utm 64 Cz 1 kurt
# utm 65 Cz 2 mean
# utm 66 Cz 2 median
# utm 67 Cz 2 std
# utm 68 Cz 2 skew
# utm 69 Cz 2 kurt
# utm 70 Cz 5 mean
# utm 71 Cz 5 median
# utm 72 Cz 5 std
# utm 73 Cz 5 skew
# utm 74 Cz 5 kurt
# utm 75 Cz 10 mean
# utm 76 Cz 10 median
# utm 77 Cz 10 std
# utm 78 Cz 10 skew
# utm 79 Cz 10 kurt
# utm 80 Cz 20 mean
# utm 81 Cz 20 median
# utm 82 Cz 20 std
# utm 83 Cz 20 skew
# utm 84 Cz 20 kurt
# utm 85 Cz 60 mean
# utm 86 Cz 60 median
# utm 87 Cz 60 std
# utm 88 Cz 60 skew
# utm 89 Cz 60 kurt
# utm 90 Laplacian 1 mean
# utm 91 Laplacian 1 median
# utm 92 Laplacian 1 std
# utm 93 Laplacian 1 skew
# utm 94 Laplacian 1 kurt
# utm 95 Laplacian 2 mean
# utm 96 Laplacian 2 median
# utm 97 Laplacian 2 std
# utm 98 Laplacian 2 skew
# utm 99 Laplacian 2 kurt
# utm 100 Laplacian 5 mean
# utm 101 Laplacian 5 median
# utm 102 Laplacian 5 std
# utm 103 Laplacian 5 skew
# utm 104 Laplacian 5 kurt
# utm 105 Laplacian 10 mean
# utm 106 Laplacian 10 median
# utm 107 Laplacian 10 std
# utm 108 Laplacian 10 skew
# utm 109 Laplacian 10 kurt
# utm 110 Laplacian 20 mean
# utm 111 Laplacian 20 median
# utm 112 Laplacian 20 std
# utm 113 Laplacian 20 skew
# utm 114 Laplacian 20 kurt
# utm 115 Laplacian 60 mean
# utm 116 Laplacian 60 median
# utm 117 Laplacian 60 std
# utm 118 Laplacian 60 skew
# utm 119 Laplacian 60 kurt

# %%
lowest_pval_df
# Out:
#             Montage SegLength Combiner Feature Index LowestPValue
# cc              CAR        20     skew            59     0.019564
# cwt       BipolarDB        20     skew           326     0.017496
# dwt       Laplacian         2     kurt             6     0.002747
# gcc             CAR        20     kurt             6     0.016973
# gplv           None      None     None          None          inf
# plv       BipolarDB         1     skew           335     0.022976
# mst       BipolarDB         1     skew            54     0.045133
# sst             CAR         5      std             1     0.046021
# spectral  Laplacian         1      std            18     0.033367
# utm              Cz        20     kurt            63     0.025308

# %%
significant_features_df
# Out:
#    FeatureName    Montage SegLength Combiner FeaturesIndexs   PValues
# 0           cc        CAR        20     skew             59  0.019564
# 1           cc  BipolarDB        10      std             36  0.046697
# 2          cwt  BipolarDB        20     skew            326  0.017496
# 3          cwt         Cz        20     skew            222  0.017496
# 4          dwt  Laplacian         2     skew              6  0.006158
# 5          dwt  Laplacian         2     skew              7  0.029498
# 6          dwt  Laplacian         2     kurt              6  0.002747
# 7          gcc        CAR        20     kurt              6  0.016973
# 8          plv  BipolarDB         1     skew            335  0.022976
# 9          plv         Cz        60      std            330  0.027550
# 10         mst  BipolarDB         1     skew             54  0.045133
# 11         sst        CAR         5      std              1  0.046021
# 12    spectral         Cz         5     kurt             24  0.035708
# 13    spectral  Laplacian         1      std             18  0.033367
# 14         utm        CAR        60     skew             63  0.049091
# 15         utm         Cz        20     kurt             63  0.025308

# %%
effect_sizes = []
for index, row in significant_features_df.iterrows():
    feature_name = row['FeatureName']
    montage = row['Montage']
    seg_length = row['SegLength']
    combiner = row['Combiner']
    feature_index = row['FeaturesIndexs']
    p_value = row['PValues']


    feature_file = f"{feature_name}_{montage}_{seg_length}s_{combiner}.npy"
    features = np.load(os.path.join(feature_path, feature_file), allow_pickle=True)
    features = handle_complex_numbers(features)

    healthy_values = features[labels == 0][:, feature_index]
    epileptic_values = features[labels == 1][:, feature_index]

    n1 = len(healthy_values)
    n2 = len(epileptic_values)
    u_stat, _ = mannwhitneyu(healthy_values, epileptic_values)

    r_rb = 1 - (2 * u_stat) / (n1 * n2)
    effect_sizes.append({
        "FeatureName": feature_name,
        "Montage": montage,
        "SegLength": seg_length,
        "Combiner": combiner,
        "FeatureIndex": feature_index,
        "PValue": p_value,
        "EffectSize": r_rb
    })

effect_sizes_df = pd.DataFrame(effect_sizes)
effect_sizes_df
# Out:
#    FeatureName    Montage  SegLength Combiner  FeatureIndex    PValue  \
# 0           cc        CAR         20     skew            59  0.019564
# 1           cc  BipolarDB         10      std            36  0.046697
# 2          cwt  BipolarDB         20     skew           326  0.017496
# 3          cwt         Cz         20     skew           222  0.017496
# 4          dwt  Laplacian          2     skew             6  0.006158
# 5          dwt  Laplacian          2     skew             7  0.029498
# 6          dwt  Laplacian          2     kurt             6  0.002747
# 7          gcc        CAR         20     kurt             6  0.016973
# 8          plv  BipolarDB          1     skew           335  0.022976
# 9          plv         Cz         60      std           330  0.027550
# 10         mst  BipolarDB          1     skew            54  0.045133
# 11         sst        CAR          5      std             1  0.046021
# 12    spectral         Cz          5     kurt            24  0.035708
# 13    spectral  Laplacian          1      std            18  0.033367
# 14         utm        CAR         60     skew            63  0.049091
# 15         utm         Cz         20     kurt            63  0.025308
#
#     EffectSize
# 0     0.417822
# 1     0.391089
# 2     0.446535
# 3     0.446535
# 4     0.471287
# 5     0.432673
# 6     0.490099
# 7    -0.361386
# 8     0.456436
# 9    -0.451980
# 10    0.382178
# 11   -0.383168
# 12    0.383663
# 13   -0.387129
# 14    0.402970
# 15    0.419307

# %%
#print in a 4x4 grid the boxplots of the features with the lowest p-values, include effect size  and p value in the title
# one plot per each row of effect_sizes_df, separating epileptic and healthy values
fig, axes = plt.subplots(4, 4, figsize=(20, 20))
for i, (index, row) in enumerate(effect_sizes_df.iterrows()):
    feature_name = row['FeatureName']
    montage = row['Montage']
    seg_length = row['SegLength']
    combiner = row['Combiner']
    feature_index = row['FeatureIndex']
    p_value = row['PValue']
    effect_size = row['EffectSize']

    feature_file = f"{feature_name}_{montage}_{seg_length}s_{combiner}.npy"
    features = np.load(os.path.join(feature_path, feature_file), allow_pickle=True)
    features = handle_complex_numbers(features)

    ax = axes[i // 4, i % 4]

    print(feature_name)
    
    healthy_values = features[labels == 0][:, feature_index]
    epileptic_values = features[labels == 1][:, feature_index]

    sns.boxplot(data=[healthy_values, epileptic_values], ax=ax)
    ax.set_title(f"{feature_name} - {montage} - {seg_length}s - {combiner}\n"
                 f"Feature Index: {feature_index}, P-Value: {p_value:.4f},\n Effect Size: {effect_size:.4f}")
    ax.set_xticks([0, 1])
    ax.set_xticklabels(['Healthy', 'Epileptic'])
plt.tight_layout()
# Out:
# cc
# cc
# cwt
# cwt
# dwt
# dwt
# dwt
# gcc
# plv
# plv
# mst
# sst
# spectral
# spectral
# utm
# utm
